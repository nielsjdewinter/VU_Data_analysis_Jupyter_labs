# %% [markdown]
# # Lab 01: Correlation and Regression
#
# In this lab, you will experiment with the tools in Python used to test correlation and regression.
# We will start with simple correlation, linear and non-linear regression and work towards multiple and logistic regression in the fo
